# %%
# !cl
# Out:
# ����: cl [ option... ] filename... [ /link linkoption... ]
# Microsoft (R) C/C++ ����ȭ �����Ϸ� ���� 19.44.35221(x64)
# Copyright (c) Microsoft Corporation. All rights reserved.

# %%
# Map 만들기

from NeuroMap import Map, Cell, Arrow
from torch.nn import Linear, Softmax
from NeuroMap.soma import Test

L1 = Linear(10, 20)
L2 = Linear(20, 30)
SM = Softmax(dim=1)
L3 = Linear(30, 5)
DT = Test()

model = Map([
    [Cell(L1, Arrow.RIGHT), Cell(L2, Arrow.DOWN)],
    [Cell(L3, Arrow.STOP),  Cell(DT, Arrow.LEFT)]
    ])
# Out:
# c:\Users\rrayy\Desktop\NeuroMap\.conda\Lib\site-packages\setuptools\_distutils\_msvccompiler.py:12: UserWarning: _get_vc_env is private; find an alternative (pypa/distutils#340)
#   warnings.warn(

# %%
# 손실함수, 옵티마이저 설정

import torch.nn as nn
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# 랜덤 데이터 생성
# 100개의 샘플, 입력 크기 10, 클래스 5개짜리 문제

import torch

X = torch.randn(100, 10)
y = torch.randint(0, 5, (100,))

# %%
# 학습 루프

epochs = 30
for epoch in range(epochs):

    optimizer.zero_grad()

    # NeuroMap은 입력을 던지면 자동으로 Arrow를 따라 흐름을 계산함
    outputs = model(X)

    loss = criterion(outputs, y)
    loss.backward()
    optimizer.step()

    print(f"[Epoch {epoch+1}/{epochs}] Loss = {loss.item():.4f}")

print("학습 완료!")
# Out:
# [Epoch 1/30] Loss = 1.6692
# [Epoch 2/30] Loss = 1.6561
# [Epoch 3/30] Loss = 1.6435
# [Epoch 4/30] Loss = 1.6315
# [Epoch 5/30] Loss = 1.6199
# [Epoch 6/30] Loss = 1.6088
# [Epoch 7/30] Loss = 1.5982
# [Epoch 8/30] Loss = 1.5881
# [Epoch 9/30] Loss = 1.5784
# [Epoch 10/30] Loss = 1.5692
# [Epoch 11/30] Loss = 1.5604
# [Epoch 12/30] Loss = 1.5520
# [Epoch 13/30] Loss = 1.5440
# [Epoch 14/30] Loss = 1.5363
# [Epoch 15/30] Loss = 1.5290
# [Epoch 16/30] Loss = 1.5221
# [Epoch 17/30] Loss = 1.5154
# [Epoch 18/30] Loss = 1.5091
# [Epoch 19/30] Loss = 1.5031
# [Epoch 20/30] Loss = 1.4973
# [Epoch 21/30] Loss = 1.4919
# [Epoch 22/30] Loss = 1.4866
# [Epoch 23/30] Loss = 1.4816
# [Epoch 24/30] Loss = 1.4768
# [Epoch 25/30] Loss = 1.4723
# [Epoch 26/30] Loss = 1.4679
# [Epoch 27/30] Loss = 1.4637
# [Epoch 28/30] Loss = 1.4597
# [Epoch 29/30] Loss = 1.4558
# [Epoch 30/30] Loss = 1.4520
# 학습 완료!
